# %% [markdown]
# # Problema resuelto 22: holografia y reconstruccion de informacion
#
# ## Problema
#
# Ordenar de forma guiada el vocabulario minimo de holografia, borde, bulk y reconstruccion de informacion en la discusion moderna sobre agujeros negros.
#
# ## Resultado esperado
#
# Ordenar el vocabulario minimo de holografia y reconstruccion para leer discusiones modernas sobre informacion de agujeros negros.

# %% [markdown]
# ## Paso 1. Dos descripciones de una misma fisica
#
# La intuicion holografica sugiere que cierta fisica gravitatoria en el bulk puede codificarse en una teoria sin gravedad situada en el borde. No necesitamos el formalismo completo de AdS/CFT para extraer la idea pedagogica central: la informacion puede estar organizada de forma no local.

# %%
bulk = ['geometria', 'horizonte', 'campos en el interior']
borde = ['observables duales', 'estado unitario', 'correladores']
{'bulk_demo': bulk, 'borde_demo': borde}

# %% [markdown]
# ## Paso 2. Reconstruccion
#
# Llamamos reconstruccion al problema de identificar que parte de la informacion del bulk puede recuperarse a partir de datos del borde o de observables mas globales. Esa pregunta se vuelve crucial cuando la lectura semiclasica local parece perder informacion.

# %%
preguntas = {
    'que_esta_codificado': 'informacion del bulk en observables del borde',
    'por_que_importa': 'unitaridad frente a termicidad aparente',
    'puente_con_islas': 'la region relevante para reconstruccion puede no ser ingenua'
}
preguntas

# %% [markdown]
# ## Advertencia
#
# Este cuaderno no sustituye un curso de holografia ni una derivacion de reconstruccion de wedge entanglement. Su funcion es mucho mas modesta: fijar el diccionario minimo que vuelve legibles las discusiones modernas sobre informacion de agujeros negros.

# %% [markdown]
# ## Preguntas guiadas
#
# 1. Que significa decir que una descripcion holografica puede seguir siendo unitaria?
# 2. Que problema intenta resolver la reconstruccion de informacion?
# 3. Como se conecta este cuaderno con `Tutorial/11_qft_informacion_y_agujeros_negros/06_holografia_y_reconstruccion_de_informacion.md`?
