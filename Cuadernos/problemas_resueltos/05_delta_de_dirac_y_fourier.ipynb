# %% [markdown]
# # Problema resuelto 05: Delta de Dirac y Fourier
#
# Cuaderno de apoyo para `Tutorial/00_prerrequisitos/05_delta_de_dirac_y_transformadas_de_fourier.md`.

# %% [markdown]
# ## Problema 1
#
# Usar la propiedad de la delta para evaluar:
#
# $$\int dx\,\delta(x-3)(x^2+1).$$

# %%
x = 3
resultado = x**2 + 1
resultado

# %% [markdown]
# ### Resultado
#
# La delta selecciona el valor de la funcion en $x=3$, por lo que el resultado es $10$.

# %% [markdown]
# ## Problema 2
#
# Explicar por que la identidad
#
# $$\int \frac{dk}{2\pi}e^{ik(x-y)} = \delta(x-y)$$
#
# es tan importante en QFT.

# %% [markdown]
# Porque conecta directamente la base de posiciones con la base de momentos. Esta identidad esta detras de las expansiones modales de campos, los propagadores y las reglas de Feynman en espacio de momentos.

# %% [markdown]
# ## Problema 3
#
# Interpretar la delta de cuatro-momento que aparece en un vertice:
#
# $$(2\pi)^4\delta^{(4)}\left(\sum p_{in} - \sum p_{out}\right).$$

# %% [markdown]
# Esa delta expresa conservacion del cuatro-momento total en la interaccion. Su origen profundo es la invariancia traslacional de la teoria.
