# %% [markdown]
# # Ejemplo 14: anomalia axial y cancelacion de anomalias
#
# ## Objetivo
#
# Fijar la diferencia conceptual entre anomalia axial, anomalias gauge y cancelacion de anomalias en el Modelo Estandar, sin entrar aun en una derivacion completa a nivel de lazo.

# %% [markdown]
# La idea pedagogica central es distinguir tres cosas:
#
# - una corriente axial clasica que parece conservada;
# - una anomalia cuántica que rompe esa conservacion;
# - la necesidad de cancelar anomalias gauge para que la teoria sea consistente.

# %%
anomalias_demo = {
    'axial_global': 'puede reflejar efecto cuántico real',
    'gauge': 'amenaza consistencia de la teoria',
    'cancelacion_SM': 'restriccion estructural sobre cargas y representaciones'
}
anomalias_demo

# %% [markdown]
# ## Lectura fisica
#
# La anomalia axial enseña que la cuantizacion puede modificar simetrias aparentes del nivel clasico. La cancelacion de anomalias gauge, en cambio, no es opcional: sin ella, una teoria gauge quiral pierde consistencia cuántica.

# %%
contribuciones_demo = np.array([1.0, -1.0, 0.5, -0.5])
contribuciones_demo.sum()

# %% [markdown]
# ## Advertencia
#
# La suma de la celda anterior es solo una imagen abstracta de cancelacion. No representa los coeficientes reales del Modelo Estandar, pero ayuda a fijar la intuicion de que la consistencia gauge exige una cancelacion global entre contribuciones de distintos campos quirales.

# %% [markdown]
# ## Preguntas guiadas
#
# 1. Que diferencia conceptual hay entre anomalia axial y anomalia gauge?
# 2. Por que una anomalia gauge compromete la consistencia de la teoria?
# 3. Como se conecta este cuaderno con `Tutorial/99_apendices/anomalia_axial_y_cancelacion_de_anomalias.md`?
