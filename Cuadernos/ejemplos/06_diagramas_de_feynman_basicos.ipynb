# %% [markdown]
# # Ejemplo 06: Diagramas de Feynman basicos
#
# Notebook asociado a `Tutorial/05_interacciones_y_perturbaciones/02_diagramas_de_feynman_y_reglas.md`.

# %% [markdown]
# ## Objetivo
#
# Resumir visualmente los ingredientes de un diagrama:
#
# - lineas externas;
# - propagadores;
# - vertices;
# - lazos;
# - orden perturbativo.
