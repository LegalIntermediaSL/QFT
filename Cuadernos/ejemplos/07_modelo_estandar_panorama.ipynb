# %% [markdown]
# # Ejemplo 07: Panorama del Modelo Estandar
#
# Notebook asociado a `Tutorial/10_modelo_estandar/01_lagrangiano_del_modelo_estandar.md`.

# %% [markdown]
# ## Objetivo
#
# Organizar por bloques el Lagrangiano del Modelo Estandar:
#
# - gauge;
# - fermionico;
# - Higgs;
# - Yukawa.
