# %% [markdown]
# # Ejemplo 13: simetrias discretas y CPT
#
# ## Objetivo
#
# Fijar de forma compacta la diferencia entre $C$, $P$, $T$ y la combinacion $CPT$, y reforzar por que la violacion de una simetria discreta concreta no contradice automaticamente la consistencia estructural de una QFT relativista.

# %% [markdown]
# Las simetrias discretas mas importantes son:
#
# - $C$: conjugacion de carga;
# - $P$: paridad;
# - $T$: inversion temporal.
#
# La combinacion $CPT$ ocupa un lugar especial porque el teorema CPT conecta su invariancia con la localidad, la relatividad y la unitaridad de la teoria.

# %%
transformaciones = {
    'C': 'intercambia particulas y antiparticulas',
    'P': 'invierte orientacion espacial',
    'T': 'invierte el sentido temporal',
    'CPT': 'combinacion estructuralmente privilegiada'
}
transformaciones

# %% [markdown]
# ## Lectura fisica
#
# El sector debil viola paridad y puede violar $CP$, pero eso no significa que viole necesariamente $CPT$. Justamente aqui se vuelve util distinguir entre simetrias discretas individuales y la combinacion completa protegida por el teorema CPT.

# %%
violaciones_demo = {
    'paridad_en_debil': True,
    'CP_en_sabor': True,
    'CPT_en_QFT_local_relativista': False
}
violaciones_demo

# %% [markdown]
# ## Advertencia
#
# La ultima celda no prueba ningun teorema. Solo organiza la intuicion minima: violar $P$ o incluso $CP$ no equivale a violar $CPT$. El valor del cuaderno es fijar ese mapa conceptual antes de volver al tratamiento mas formal.

# %% [markdown]
# ## Preguntas guiadas
#
# 1. Por que la violacion de paridad no contradice el teorema CPT?
# 2. Que hace especial a la combinacion $CPT$ frente a $C$, $P$ y $T$ por separado?
# 3. Como se conecta este cuaderno con `Tutorial/99_apendices/simetrias_discretas_cpt_y_anomalias.md`?
