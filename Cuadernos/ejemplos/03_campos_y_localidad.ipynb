# %% [markdown]
# # Ejemplo 03: Campos y localidad
#
# Notebook asociado a `Tutorial/02_relatividad_y_campos/02_campos_localidad_y_causalidad.md`.

# %% [markdown]
# ## Idea central
#
# Comparar conceptualmente:
#
# - teoria de una particula con numero fijo;
# - teoria de campos local;
# - papel de la microcausalidad.
