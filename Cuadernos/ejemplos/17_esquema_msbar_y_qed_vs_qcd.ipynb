# %% [markdown]
# # Ejemplo 17: esquema MS-bar y QED vs QCD
#
# ## Objetivo
#
# Fijar de manera breve la diferencia cualitativa entre el running coupling en QED y en QCD y el papel practico del esquema $\overline{\mathrm{MS}}$.
#
# ## Resultado esperado
#
# Distinguir el papel del esquema MS-bar y la diferencia cualitativa entre el running de QED y QCD.

# %% [markdown]
# El mensaje pedagogico central es doble:
#
# 1. el esquema $\overline{\mathrm{MS}}$ organiza como redefinimos parametros al renormalizar;
# 2. el signo de la funcion beta cambia de forma profunda la fisica de escalas.

# %%
import numpy as np

mu = np.array([1.0, 10.0, 100.0])
alpha_qed = np.round(1/137 + 0.0008 * np.log(mu), 6)
alpha_qcd = np.round(0.35 - 0.035 * np.log(mu), 6)
{'mu': mu.tolist(), 'alpha_qed_demo': alpha_qed.tolist(), 'alpha_qcd_demo': alpha_qcd.tolist()}

# %% [markdown]
# ## Lectura fisica
#
# La tabla de juguete anterior no pretende reproducir valores reales, pero si fijar la intuicion mas importante: en QED el acoplamiento crece lentamente con la escala, mientras que en QCD disminuye a altas energias. Eso refleja la diferencia entre una teoria abeliana y una no abeliana con autoacoplamiento del sector gauge.

# %%
esquemas = {
    'MS': 'sustrae polos en 1/epsilon',
    'MS_bar': 'sustrae polos y constantes asociadas a regularizacion dimensional'
}
esquemas

# %% [markdown]
# ## Advertencia
#
# Las celdas anteriores no sustituyen un calculo real de funcion beta ni una discusion completa de esquemas de renormalizacion. Su funcion es ordenar la intuicion: cambiar de esquema no cambia observables completos, pero si cambia la forma intermedia de los parametros renormalizados.

# %% [markdown]
# ## Preguntas guiadas
#
# 1. Por que el signo de la funcion beta importa tanto en la interpretacion fisica?
# 2. Que hace practicamente el esquema $\overline{\mathrm{MS}}$?
# 3. Como se conecta este cuaderno con `Tutorial/09_renormalizacion/05_esquema_msbar_y_qed_vs_qcd.md`?
