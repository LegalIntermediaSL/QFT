# %% [markdown]
# # Ejemplo 05: Cuantizacion del campo escalar
#
# Notebook asociado a `Tutorial/04_cuantizacion_del_campo_escalar/02_cuantizacion_canonica_y_espacio_de_fock.md`.

# %% [markdown]
# ## Objetivo
#
# Reforzar la relacion entre:
#
# - expansion en modos;
# - operadores de creacion y aniquilacion;
# - estados del espacio de Fock.
