# %% [markdown]
# # Ejemplo 02: Principios estructurales y restricciones
#
# Notebook asociado a `Tutorial/01_fundamentos_conceptuales/02_principios_estructurales_de_la_qft.md`.

# %% [markdown]
# ## Objetivo
#
# Organizar de forma visual y comparativa los principios que restringen una QFT consistente:
#
# - relatividad especial;
# - invarianza de Poincare;
# - microcausalidad;
# - unitaridad;
# - renormalizacion.

# %%
principios = {
    'relatividad': 'covariancia y estructura causal',
    'microcausalidad': 'no senalizacion superluminal',
    'unitaridad': 'conservacion de probabilidad',
    'spin-estadistica': 'bosones y fermiones',
    'renormalizacion': 'control de escalas y divergencias'
}
principios
