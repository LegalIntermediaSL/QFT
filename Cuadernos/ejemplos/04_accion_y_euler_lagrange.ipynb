# %% [markdown]
# # Ejemplo 04: Accion y Euler-Lagrange
#
# Notebook asociado a `Tutorial/03_accion_y_simetrias/01_principio_de_accion_y_ecuaciones_de_campo.md`.

# %% [markdown]
# ## Objetivo
#
# Ilustrar la derivacion de Euler-Lagrange para un campo escalar libre y comparar accion, densidad lagrangiana y ecuacion de movimiento.
